# %% [markdown]
# Oxytocin Individual

# %%
import numpy as np
import pandas as pd
import tdt
import matplotlib.pyplot as plt
import os
from scipy.signal import butter, filtfilt, find_peaks

from trial_class import Trial

# %%
# NAc
trial_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy_1_1-250226-135634"
brain_region = '#FFAF00'

# %%
# s1 = tdt.read_block(trial_path)

# %%
trial = Trial(trial_path)
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy_1_1-250226-135634\Notes.txt
# read from t=0s to t=286.55s
# Point events extracted and stored.

# %%
trial.behaviors.head()
# Out:
#       Bout     Behavior  Event_Start   Event_End  Duration (s)
# 0  Event-1  Interaction   133.495521  133.495521             0
# 1  Event-2  Interaction   138.608476  138.608476             0
# 2  Event-3  Interaction   140.647465  140.647465             0
# 3  Event-4  Interaction   145.463542  145.463542             0
# 4  Event-5  Interaction   153.816596  153.816596             0

# %%
trial.remove_initial_LED_artifact(t=30)
trial.remove_final_data_segment(t = 10)

trial.smooth_and_apply(window_len=int(trial.fs)*2)
trial.apply_ma_baseline_drift()
trial.align_channels()
trial.compute_dFF()
# baseline_start, baseline_end = trial.find_baseline_period()  
# trial.compute_zscore(method = 'baseline', baseline_start = baseline_start, baseline_end = baseline_end)
trial.compute_zscore(method = 'standard')

trial.verify_signal()

# %%
trial.plot_behavior_event()
