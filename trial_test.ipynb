# %% [markdown]
# Oxytocin Individual

# %%
import numpy as np
import pandas as pd
import tdt
import matplotlib.pyplot as plt
import os
from scipy.signal import butter, filtfilt, find_peaks

from trial_class import Trial

# %%
trial_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\ox_data_pinch_test\oxy_1_1-250226-135634"
csv_path = r"oxy_csvs\oxy_1_1-250226-135634.csv"
brain_region = '#FFAF00'

# %%
# s1 = tdt.read_block(trial_path)

# %%
trial = Trial(trial_path)
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\ox_data_pinch_test\oxy_1_1-250226-135634\Notes.txt
# read from t=0s to t=286.55s

# %%
trial.behaviors.tail()
# Out:
#         Bout     Behavior  Event_Start   Event_End  Duration (s)
# 11  Event-12  Interaction   169.413345  169.413345             0
# 12  Event-13  Interaction   182.365716  182.365716             0
# 13  Event-14  Interaction   189.149348  189.149348             0
# 14  Event-15  Interaction   197.893652  197.893652             0
# 15  Event-16  Interaction   200.269332  200.269332             0

# %%
trial.remove_initial_LED_artifact(t=30)
# trial.remove_final_data_segment(t = 10)

trial.smooth_and_apply(window_len=int(trial.fs)*2)
trial.apply_ma_baseline_drift()
trial.align_channels()
trial.compute_dFF()
# baseline_start, baseline_end = trial.find_baseline_period()  
# trial.compute_zscore(method = 'baseline', baseline_start = baseline_start, baseline_end = baseline_end)
trial.compute_zscore(method = 'standard')

trial.verify_signal()

# %%
trial.plot_behavior_event()
