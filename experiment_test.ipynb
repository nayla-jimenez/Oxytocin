# %% [markdown]
# # Plotting all files

# %%
from experiment_class import Experiment

# %%
experiment_path = r"C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221"
fake_behavior_path = r"fake"

# %%
exp = Experiment(experiment_path,fake_behavior_path)
# Out:
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy2_2-250226-142650\Notes.txt
# read from t=0s to t=321.24s
# Point events extracted and stored.
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy2_2-250226-143229\Notes.txt
# read from t=0s to t=325.94s
# Point events extracted and stored.
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy_1-250226-101914\Notes.txt
# read from t=0s to t=321.94s
# Point events extracted and stored.
# Found Synapse note file: C:\Users\alber\OneDrive\Desktop\PC_Lab\oxytocin\ox data 1\ox data\2_26_25_Oxytocin_Pilot-250226-103221\oxy_1-250226-103221\Notes.txt
# read from t=0s to t=205.34s
# Point events extracted and stored.
# ...

# %%
exp.default_batch_process()
# Out:
# Processing oxy2_2-250226-142650...
# Processing oxy2_2-250226-143229...
# Processing oxy_1-250226-101914...
# Processing oxy_1-250226-103221...
# Processing oxy_1-250226-103750...
# Processing oxy_1-250226-104223...
# Processing oxy_1_1-250226-135634...
# Processing oxy_1_1-250226-140211...
# Processing oxy_2-250226-105631...
# Processing oxy_2-250226-110001...
# Processing oxy_2-250226-110356...
# Processing oxy_2-250226-111424...

# %%
exp.plot_all_traces()
